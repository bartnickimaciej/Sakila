# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Opening SQL Data

# %%
connection = sqlite3.connect('sakila.db')

# %%
query = '''
SELECT address.address, city.city, country.country
FROM address
JOIN city ON address.city_id = city.city_id
JOIN country ON city.country_id = country.country_id
'''

# %% [markdown]
# #### Creating DF + data cleaning

# %%
df = pd.read_sql_query(query, connection)

# %%
connection.close()

# %%
df
# Out:
#                       address        city      country
# 0           47 MySakila Drive  Lethbridge       Canada
# 1          28 MySQL Boulevard   Woodridge    Australia
# 2           23 Workhaven Lane  Lethbridge       Canada
# 3        1411 Lillydale Drive   Woodridge    Australia
# 4              1913 Hanoi Way      Sasebo        Japan
# ..                        ...         ...          ...
# 598       844 Bucuresti Place     Jinzhou        China
# 599  1101 Bucuresti Boulevard      Patras       Greece
# 600    1103 Quilmes Boulevard     Sullana         Peru
# 601       1331 Usak Boulevard    Lausanne  Switzerland
# 602      1325 Fukuyama Street       Tieli        China
#
# [603 rows x 3 columns]

# %%
poland_locations = df.loc[df['country'] == 'Poland'].copy()

# %%
poland_locations
# Out:
#                          address             city country
# 131     1050 Garden Grove Avenue  Jastrzebie-Zdrj  Poland
# 273               906 Goinia Way           Kalisz  Poland
# 321              1769 Iwaki Lane        Bydgoszcz  Poland
# 383  1642 Charlotte Amalie Drive            Tychy  Poland
# 504       414 Mandaluyong Street           Lublin  Poland
# 561         505 Madiun Boulevard          Wroclaw  Poland
# 574   1501 Pangkal Pinang Avenue            Plock  Poland
# 575          1405 Hagonoy Avenue      Czestochowa  Poland

# %%
poland_locations.loc[poland_locations['city'] == "Jastrzebie-Zdrj", 'city'] = "Jastrzębie-Zdroj"

# %%
poland_locations
# Out:
#                          address              city country
# 131     1050 Garden Grove Avenue  Jastrzębie-Zdroj  Poland
# 273               906 Goinia Way            Kalisz  Poland
# 321              1769 Iwaki Lane         Bydgoszcz  Poland
# 383  1642 Charlotte Amalie Drive             Tychy  Poland
# 504       414 Mandaluyong Street            Lublin  Poland
# 561         505 Madiun Boulevard           Wroclaw  Poland
# 574   1501 Pangkal Pinang Avenue             Plock  Poland
# 575          1405 Hagonoy Avenue       Czestochowa  Poland

# %% [markdown]
# #### Decoding coordinates with Nominatim

# %%
from geopy.geocoders import Nominatim

# %%
geolocator = Nominatim(user_agent="geoapiExercises")

# %%
def update_coordinates(data):
    for index, city in data['city'].items():
        location = geolocator.geocode(f"{city}, Poland", timeout=5)
        if location:
            data.loc[index, 'latitude'] = location.latitude
            data.loc[index, 'longitude'] = location.longitude
        else:
            print(f"Geocoding failed for city: {city}")

    return data

# %%
poland_locations = update_coordinates(poland_locations.copy())

# %%
print(poland_locations[['city', 'latitude', 'longitude']])
# Out:
#                  city   latitude  longitude
# 131  Jastrzębie-Zdroj  49.960679  18.599372
# 273            Kalisz  51.747365  18.079590
# 321         Bydgoszcz  53.129746  18.029370
# 383             Tychy  50.114397  18.996593
# 504            Lublin  51.250559  22.570102
# 561           Wroclaw  51.108978  17.032669
# 574             Plock  52.546452  19.700861
# 575       Czestochowa  50.809000  19.124409

# %% [markdown]
# #### Showing locations on the map with Folium

# %%
import folium

# %%
mean_latitude = poland_locations['latitude'].mean()
mean_longitude = poland_locations['longitude'].mean()

# %%
map = folium.Map(location=[mean_latitude, mean_longitude], zoom_start=7, title='Sakila locations in Poland')

# %%
for _, row in poland_locations.iterrows():
    folium.Marker([row['latitude'], row['longitude']], tooltip=row['city']).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4f95e4b2661f0958f7b1233ca1e68763 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4f95e4b2661f0958f7b1233ca1e68763&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4f95e4b2661f0958f7b1233ca1e68763 = L.map(
#                 &quot;map_4f95e4b2661f0958f7b1233ca1e68763&quot;,
#                 {
#                     center: [51.333397018750006, 19.016620701942877],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     title: &quot;Sakila locations in Poland&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_75e3f199366bdcc58f603f34f750ba9d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_75e3f199366bdcc58f603f34f750ba9d.addTo(map_4f95e4b2661f0958f7b1233ca1e68763);
#
#
#             var marker_1d338e32cbe0af89df67530c3ac9ca1f = L.marker(
#                 [49.96067945, 18.599371941184817],
#                 {}
#             ).addTo(map_4f95e4b2661f0958f7b1233ca1e68763);
#
#
#             marker_1d338e32cbe0af89df67530c3ac9ca1f.bindTooltip(
#                 `&lt;div&gt;
#                      Jastrzębie-Zdroj
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bbc2b522f6b3d40df5c2665900e83546 = L.marker(
#                 [51.74736505, 18.079590087700034],
#                 {}
#             ).addTo(map_4f95e4b2661f0958f7b1233ca1e68763);
#
#
#             marker_bbc2b522f6b3d40df5c2665900e83546.bindTooltip(
#                 `&lt;div&gt;
#                      Kalisz
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_842d9f8ea89435ccc64d7d56cb8db018 = L.marker(
#                 [53.12974625, 18.029369658534854],
#                 {}
#             ).addTo(map_4f95e4b2661f0958f7b1233ca1e68763);
#
#
#             marker_842d9f8ea89435ccc64d7d56cb8db018.bindTooltip(
#                 `&lt;div&gt;
#                      Bydgoszcz
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8ed3f3942ab4572348aaa9cab53c2a9f = L.marker(
#                 [50.114397, 18.9965933],
#                 {}
#             ).addTo(map_4f95e4b2661f0958f7b1233ca1e68763);
#
#
#             marker_8ed3f3942ab4572348aaa9cab53c2a9f.bindTooltip(
#                 `&lt;div&gt;
#                      Tychy
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_84ad1a2823cd39825260d80e03cd5ab7 = L.marker(
#                 [51.250559, 22.5701022],
#                 {}
#             ).addTo(map_4f95e4b2661f0958f7b1233ca1e68763);
#
#
#             marker_84ad1a2823cd39825260d80e03cd5ab7.bindTooltip(
#                 `&lt;div&gt;
#                      Lublin
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ed76af149a8d9ac5ddcff04ffd2bc10e = L.marker(
#                 [51.1089776, 17.0326689],
#                 {}
#             ).addTo(map_4f95e4b2661f0958f7b1233ca1e68763);
#
#
#             marker_ed76af149a8d9ac5ddcff04ffd2bc10e.bindTooltip(
#                 `&lt;div&gt;
#                      Wroclaw
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6b80e0db21d0e265880ca3525614fae9 = L.marker(
#                 [52.5464521, 19.7008606],
#                 {}
#             ).addTo(map_4f95e4b2661f0958f7b1233ca1e68763);
#
#
#             marker_6b80e0db21d0e265880ca3525614fae9.bindTooltip(
#                 `&lt;div&gt;
#                      Plock
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_34d65431b0e3cbf9694e14525a873c0b = L.marker(
#                 [50.8089997, 19.1244089281233],
#                 {}
#             ).addTo(map_4f95e4b2661f0958f7b1233ca1e68763);
#
#
#             marker_34d65431b0e3cbf9694e14525a873c0b.bindTooltip(
#                 `&lt;div&gt;
#                      Czestochowa
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
